# %%
import os
import subprocess
from pathlib import Path
import pdb

# %%
home_dir = str(Path.home())
out_dir = f"{home_dir}/nuscenes_dataset/inference_results"
pcd_path = f"{home_dir}/software/mmdetection3d/data/nuscenes/samples/LIDAR_TOP/"

pcd_list = os.listdir(pcd_path)

# %%
# python3 demo/pcd_demo.py ~/nuscenes_dataset/nuscenes_mini/sweeps/LIDAR_TOP/n008-2018-08-01-15-16-36-0400__LIDAR_TOP__1533151603597909.pcd.bin configs/pointpillars/pointpillars_hv_fpn_sbn-all_8xb4-2x_nus-3d.py nuscenes_path_files/hv_pointpillars_fpn_sbn-all_4x8_2x_nus-3d_20210826_104936-fca299c1.pth  --device cuda
# python3 demo/pcd_demo.py ~/nuscenes_dataset/nuscenes_mini/sweeps/LIDAR_TOP/n008-2018-08-01-15-16-36-0400__LIDAR_TOP__1533151603597909.pcd.bin configs/pointpillars/pointpillars_hv_fpn_sbn-all_8xb4-2x_nus-3d.py nuscenes_path_files/hv_pointpillars_fpn_sbn-all_4x8_2x_nus-3d_20210826_104936-fca299c1.pth  --device cuda

configs_path = "configs/pointpillars/pointpillars_hv_fpn_sbn-all_8xb4-2x_nus-3d.py"
checkpoint_path = "nuscenes_path_files/hv_pointpillars_fpn_sbn-all_4x8_2x_nus-3d_20210826_104936-fca299c1.pth"

i = 0
for pcd in pcd_list[:10]:
    path = Path(f"{home_dir}/software/mmdetection3d/data/nuscenes/samples/LIDAR_TOP/{pcd}").absolute()
    # print(path)
    if path.exists():
        cmd = f'python3 demo/pcd_demo.py {str(path)} {configs_path} {checkpoint_path} --device cuda --out-dir {out_dir}'
    else:
        pdb.set_trace()
        
    subprocess.run(cmd, cwd=f"{home_dir}/software/mmdetection3d/", shell=True)

print(i)

# cmd = f'python3 demo/pcd_demo.py data/nuscenes/{filename} {configs_path} {checkpoint_path} --device cuda'
# print(cmd)
# subprocess.run(cmd, cwd = "/home/ranai/software/mmdetection3d/", shell=True)
# Out:
# /home/ranai/software/mmdetection3d/mmdet3d/models/dense_heads/anchor3d_head.py:94: UserWarning: dir_offset and dir_limit_offset will be depressed and be incorporated into box coder in the future
#   warnings.warn(
# Loads checkpoint by local backend from path: nuscenes_path_files/hv_pointpillars_fpn_sbn-all_4x8_2x_nus-3d_20210826_104936-fca299c1.pth
# 12/08 18:02:43 - mmengine - WARNING - Failed to search registry with scope "mmdet3d" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet3d" is a correct scope, or whether the registry is initialized.
# /home/ranai/.local/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
# /home/ranai/.local/lib/python3.8/site-packages/torch/functional.py:504: 90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass
# the indexing argument. (Triggered internally at
# ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 12/08 18:02:45 - mmengine - INFO - results have been saved at /home/ranai/nuscenes_dataset/inference_results
# /home/ranai/software/mmdetection3d/mmdet3d/models/dense_heads/anchor3d_head.py:94: UserWarning: dir_offset and dir_limit_offset will be depressed and be incorporated into box coder in the future
#   warnings.warn(
# Loads checkpoint by local backend from path: nuscenes_path_files/hv_pointpillars_fpn_sbn-all_4x8_2x_nus-3d_20210826_104936-fca299c1.pth
# 12/08 18:02:49 - mmengine - WARNING - Failed to search registry with scope "mmdet3d" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet3d" is a correct scope, or whether the registry is initialized.
# /home/ranai/.local/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
# /home/ranai/.local/lib/python3.8/site-packages/torch/functional.py:504: 90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass
# the indexing argument. (Triggered internally at
# ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 12/08 18:02:51 - mmengine - INFO - results have been saved at /home/ranai/nuscenes_dataset/inference_results
# /home/ranai/software/mmdetection3d/mmdet3d/models/dense_heads/anchor3d_head.py:94: UserWarning: dir_offset and dir_limit_offset will be depressed and be incorporated into box coder in the future
#   warnings.warn(
# Loads checkpoint by local backend from path: nuscenes_path_files/hv_pointpillars_fpn_sbn-all_4x8_2x_nus-3d_20210826_104936-fca299c1.pth
# 12/08 18:02:55 - mmengine - WARNING - Failed to search registry with scope "mmdet3d" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet3d" is a correct scope, or whether the registry is initialized.
# /home/ranai/.local/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
# /home/ranai/.local/lib/python3.8/site-packages/torch/functional.py:504: 90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass
# the indexing argument. (Triggered internally at
# ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 12/08 18:02:56 - mmengine - INFO - results have been saved at /home/ranai/nuscenes_dataset/inference_results
# /home/ranai/software/mmdetection3d/mmdet3d/models/dense_heads/anchor3d_head.py:94: UserWarning: dir_offset and dir_limit_offset will be depressed and be incorporated into box coder in the future
#   warnings.warn(
# Loads checkpoint by local backend from path: nuscenes_path_files/hv_pointpillars_fpn_sbn-all_4x8_2x_nus-3d_20210826_104936-fca299c1.pth
# 12/08 18:03:00 - mmengine - WARNING - Failed to search registry with scope "mmdet3d" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet3d" is a correct scope, or whether the registry is initialized.
# /home/ranai/.local/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
# /home/ranai/.local/lib/python3.8/site-packages/torch/functional.py:504: 90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass
# the indexing argument. (Triggered internally at
# ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 12/08 18:03:02 - mmengine - INFO - results have been saved at /home/ranai/nuscenes_dataset/inference_results
# /home/ranai/software/mmdetection3d/mmdet3d/models/dense_heads/anchor3d_head.py:94: UserWarning: dir_offset and dir_limit_offset will be depressed and be incorporated into box coder in the future
#   warnings.warn(
# Loads checkpoint by local backend from path: nuscenes_path_files/hv_pointpillars_fpn_sbn-all_4x8_2x_nus-3d_20210826_104936-fca299c1.pth
# 12/08 18:03:05 - mmengine - WARNING - Failed to search registry with scope "mmdet3d" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet3d" is a correct scope, or whether the registry is initialized.
# /home/ranai/.local/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
# /home/ranai/.local/lib/python3.8/site-packages/torch/functional.py:504: 90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass
# the indexing argument. (Triggered internally at
# ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 12/08 18:03:07 - mmengine - INFO - results have been saved at /home/ranai/nuscenes_dataset/inference_results
# /home/ranai/software/mmdetection3d/mmdet3d/models/dense_heads/anchor3d_head.py:94: UserWarning: dir_offset and dir_limit_offset will be depressed and be incorporated into box coder in the future
#   warnings.warn(
# Loads checkpoint by local backend from path: nuscenes_path_files/hv_pointpillars_fpn_sbn-all_4x8_2x_nus-3d_20210826_104936-fca299c1.pth
# 12/08 18:03:11 - mmengine - WARNING - Failed to search registry with scope "mmdet3d" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet3d" is a correct scope, or whether the registry is initialized.
# /home/ranai/.local/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
# /home/ranai/.local/lib/python3.8/site-packages/torch/functional.py:504: 90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass
# the indexing argument. (Triggered internally at
# ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 12/08 18:03:12 - mmengine - INFO - results have been saved at /home/ranai/nuscenes_dataset/inference_results
# /home/ranai/software/mmdetection3d/mmdet3d/models/dense_heads/anchor3d_head.py:94: UserWarning: dir_offset and dir_limit_offset will be depressed and be incorporated into box coder in the future
#   warnings.warn(
# Loads checkpoint by local backend from path: nuscenes_path_files/hv_pointpillars_fpn_sbn-all_4x8_2x_nus-3d_20210826_104936-fca299c1.pth
# 12/08 18:03:16 - mmengine - WARNING - Failed to search registry with scope "mmdet3d" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet3d" is a correct scope, or whether the registry is initialized.
# /home/ranai/.local/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
# /home/ranai/.local/lib/python3.8/site-packages/torch/functional.py:504: 90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass
# the indexing argument. (Triggered internally at
# ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 12/08 18:03:17 - mmengine - INFO - results have been saved at /home/ranai/nuscenes_dataset/inference_results
# /home/ranai/software/mmdetection3d/mmdet3d/models/dense_heads/anchor3d_head.py:94: UserWarning: dir_offset and dir_limit_offset will be depressed and be incorporated into box coder in the future
#   warnings.warn(
# Loads checkpoint by local backend from path: nuscenes_path_files/hv_pointpillars_fpn_sbn-all_4x8_2x_nus-3d_20210826_104936-fca299c1.pth
# 12/08 18:03:21 - mmengine - WARNING - Failed to search registry with scope "mmdet3d" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet3d" is a correct scope, or whether the registry is initialized.
# /home/ranai/.local/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
# /home/ranai/.local/lib/python3.8/site-packages/torch/functional.py:504: 90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass
# the indexing argument. (Triggered internally at
# ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 12/08 18:03:23 - mmengine - INFO - results have been saved at /home/ranai/nuscenes_dataset/inference_results
# /home/ranai/software/mmdetection3d/mmdet3d/models/dense_heads/anchor3d_head.py:94: UserWarning: dir_offset and dir_limit_offset will be depressed and be incorporated into box coder in the future
#   warnings.warn(
# Loads checkpoint by local backend from path: nuscenes_path_files/hv_pointpillars_fpn_sbn-all_4x8_2x_nus-3d_20210826_104936-fca299c1.pth
# 12/08 18:03:27 - mmengine - WARNING - Failed to search registry with scope "mmdet3d" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet3d" is a correct scope, or whether the registry is initialized.
# /home/ranai/.local/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
# /home/ranai/.local/lib/python3.8/site-packages/torch/functional.py:504: 90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass
# the indexing argument. (Triggered internally at
# ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 12/08 18:03:28 - mmengine - INFO - results have been saved at /home/ranai/nuscenes_dataset/inference_results
# /home/ranai/software/mmdetection3d/mmdet3d/models/dense_heads/anchor3d_head.py:94: UserWarning: dir_offset and dir_limit_offset will be depressed and be incorporated into box coder in the future
#   warnings.warn(
# Loads checkpoint by local backend from path: nuscenes_path_files/hv_pointpillars_fpn_sbn-all_4x8_2x_nus-3d_20210826_104936-fca299c1.pth
# 12/08 18:03:32 - mmengine - WARNING - Failed to search registry with scope "mmdet3d" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet3d" is a correct scope, or whether the registry is initialized.
# /home/ranai/.local/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
# /home/ranai/.local/lib/python3.8/site-packages/torch/functional.py:504: 90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass
# the indexing argument. (Triggered internally at
# ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 12/08 18:03:33 - mmengine - INFO - results have been saved at /home/ranai/nuscenes_dataset/inference_results
# 0

# %%
# Choosing a file
from nuscenes.nuscenes import NuScenes

nusc = NuScenes(version='v1.0-trainval', dataroot = f"{home_dir}/software/mmdetection3d/data/nuscenes")
scene = nusc.scene[2]
# Out:
# ======
# Loading NuScenes tables for version v1.0-trainval...
# 23 category,
# 8 attribute,
# 4 visibility,
# 64386 instance,
# 12 sensor,
# 10200 calibrated_sensor,
# 2631083 ego_pose,
# 68 log,
# 850 scene,
# 34149 sample,
# 2631083 sample_data,
# 1166187 sample_annotation,
# 4 map,
# Done loading in 26.568 seconds.
# ======
# Reverse indexing ...
# Done reverse indexing in 6.1 seconds.
# ======

# %%
sample_token = scene['first_sample_token'] 

# At this timestep, this gives tokens for everything (anootations, sensor output, etc)
sample = nusc.get('sample', sample_token)

# %%
# at the sample timestep, what is the token for the sensor output from
sample['data']
# Out:
# {'RADAR_FRONT': 'a80ee7369c9a4a15946caa5d59155bf2',
#  'RADAR_FRONT_LEFT': 'bebde4a7c59d4a528cc1ecd7e8fafba9',
#  'RADAR_FRONT_RIGHT': '87213a6c1ff246c99c16a683bf3eb2e3',
#  'RADAR_BACK_LEFT': 'eb2974c182db46409c17557d6923e505',
#  'RADAR_BACK_RIGHT': '3ff6ecbc35f843dfbbcb39c4a786659b',
#  'LIDAR_TOP': '80a35c14dd68408d83cf0e4f814feae4',
#  'CAM_FRONT': 'b8fba7d78cf547b996c431dec1f5ee26',
#  'CAM_FRONT_RIGHT': 'ba9b6fd85aca41cda98ff0c3d5f71af6',
#  'CAM_BACK_RIGHT': '669b1e90a823418b854daa7ce5c4e9e3',
#  'CAM_BACK': 'fdb81e7a95824171bac5f2d470bba0b3',
#  'CAM_BACK_LEFT': '97bd930608044d26bf17b10ed0a54c8e',
#  'CAM_FRONT_LEFT': '9adb8200723d4223bfc48ffd2c3a7646'}

# %%
lidar_data = nusc.get('sample_data', sample['data']["LIDAR_TOP"])
filename = lidar_data['filename']
filename

# nusc.render_sample_data(lidar_data['token'])

# %%
cam_front_data = nusc.get('sample_data', sample['data']["CAM_FRONT"])
filename = cam_front_data['filename']
filename

# nusc.render_sample_data(cam_front_data['token'])

# %%
cam_back_data = nusc.get('sample_data', sample['data']["CAM_BACK"])
filename = cam_back_data['filename']
filename

# nusc.render_sample_data(cam_back_data['token'])

# %%
# for scene in nusc.scenes:
sample_token = scene['first_sample_token'] 

# At this timestep, this gives tokens for everything (anootations, sensor output, etc)
sample = nusc.get('sample', sample_token)

# at the sample timestep, what is the token for the sensor output from
# sample['data']

lidar_data = nusc.get('sample_data', sample['data']["LIDAR_TOP"])
filename = lidar_data['filename']

annotation_tokens = sample["anns"]
for annotation_token in annotation_tokens:
    nusc.get('sample_annotation', annotation_token)

# %%
# Find a scene, Find the coresponding image token , based on token, get a list of the LIDAR file AND check the LIDAR images that we have predicted
# If in the list of LIDAR files we have preocessed, the lidar file for this sample matches, then we load go through each annotation. Very Very inefficient. 

for scene in nusc.scene:
    # Get corespoding scene LIDAR TOP FILE 
    
    first_sample_token = scene['first_sample_token'] 

    # At this timestep, this gives tokens for everything (anootations, sensor output, etc)
    sample = nusc.get('sample', first_sample_token)
    
    lidar_data = nusc.get('sample_data', sample['data']["LIDAR_TOP"])
    filename = lidar_data['filename']
    
    processed_files = os.listdir("/home/ranai/software/mmdetection3d/output/preds")
    
    if filename in processed_files:
        # Found file with the same name. Now compare the annotations in this file
        sample['anns']
